# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

plt.rcParams["figure.figsize"] = [12, 10]
plt.rcParams["figure.autolayout"] = True

ax = plt.GridSpec(2, 4)
# ax.update(wspace=0.3, hspace=0.4)

w=0.1

ax1 = plt.subplot(ax[0, 0])

Metrics=['Glove']

KNN = [0.7556]
DT = [0.6667]
LGBM = [0.6789]
GB = [0.9516]
RF = [0.9666]
ETC = [0.9617]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('A', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[0, 1])

Metrics=['Word2Vec']

KNN = [0.7333]
DT = [0.6608]
LGBM = [0.6601]
GB = [0.9441]
RF = [0.9509]
ETC = [0.9053]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('B', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[0, 2])

Metrics=['FastText']

KNN = [0.7167]
DT = [0.6477]
LGBM = [0.6511]
GB = [0.9394]
RF = [0.9634]
ETC = [0.9419]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('C', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[0, 3])

Metrics=['PAAC']

KNN = [0.7000]
DT = [0.6667]
LGBM = [0.6700]
GB = [0.9439]
RF = [0.9432]
ETC = [0.9414]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('D', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[1, 0])

Metrics=['AAINDEX']

KNN = [0.6667]
DT = [0.6681]
LGBM = [0.7083]
GB = [0.9230]
RF= [0.9529]
ETC = [0.9231]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('E', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[1, 1])

Metrics=['AAC']

KNN = [0.7333]
DT = [0.6477]
LGBM = [0.6400]
GB = [0.9272]
RF = [0.9433]
ETC = [0.9043]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('F', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[1, 2])

Metrics=['DPC']

KNN = [0.6667]
DT = [0.6637]
LGBM = [0.6716]
GB = [0.9197]
RF = [0.9475]
ETC = [0.9475]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('G', weight='bold', fontsize=20,  x=-0.2, y=0.93)


ax1 = plt.subplot(ax[1, 3])

Metrics=['CKSAAP']

KNN = [0.6923]
DT = [0.6462]
LGBM = [0.7173]
GB = [0.9244]
RF = [0.9414]
ETC = [0.9319]

KNN_bar = np.arange(len(Metrics))
DT_bar=[i+w for i in KNN_bar]
LGBM_bar=[i+w for i in DT_bar]
GB_bar=[i+w for i in LGBM_bar]
RF_bar=[i+w for i in GB_bar]
ETC_bar=[i+w for i in RF_bar]

plt.bar(KNN_bar,KNN,width=w,label="Set1")
plt.bar(DT_bar,DT,width=w,label="Set2")
plt.bar(LGBM_bar,LGBM,width=w,label="Set3")
plt.bar(GB_bar,GB,width=w,label="Set4")
plt.bar(RF_bar,RF,width=w,label="Set5")
plt.bar(ETC_bar,ETC,width=w,label="Set6")

plt.xticks(KNN_bar+w+w+w/2,Metrics)
plt.xticks(fontsize=15)
plt.ylim(0.0,1.0)
plt.yticks(fontsize=12)
plt.ylabel("Accuracy",color="black",size=15)
plt.legend(fontsize=11, loc='lower center', ncol=2)
# plt.title('GloVe', fontsize=15)
plt.title('H', weight='bold', fontsize=20,  x=-0.2, y=0.93)

plt.tight_layout()
plt.savefig('Classifier Performance.png', dpi=800)
plt.savefig('Classifier Performance.pdf', dpi=800)
